# %%
#1
#aws s3 bucket config
#AAI-540 Group 3 FP

# %%
import boto3
import sagemaker
session = boto3.session.Session()
sess = sagemaker.Session()
region = session.region_name
role = sagemaker.get_execution_role()
sagemaker_session = sagemaker.Session()
bucket = sagemaker_session.default_bucket()
s3 = boto3.Session().client(service_name="s3", region_name=region)
account_id = boto3.client("sts").get_caller_identity().get("Account")
sm = boto3.Session().client(service_name="sagemaker", region_name=region)

# %%
print("Default bucket: {}".format(bucket))
# Out:
# Default bucket: sagemaker-us-east-1-342942554664

# %%
s3_private_path_csv = "s3://sagemaker-us-east-1-342942554664".format(bucket)
# %store s3_private_path_csv
# %store
# Out:
# Stored 's3_private_path_csv' (str)
# Stored variables and their in-db values:
# s3_private_path_csv             -> 's3://sagemaker-us-east-1-342942554664'

# %%
# !aws s3 cp aimodelpoll.csv s3://sagemaker-us-east-1-342942554664/aimodelpoll.csv
# Out:
# upload: ./aimodelpoll.csv to s3://sagemaker-us-east-1-342942554664/aimodelpoll.csv

# %%
# !aws s3 cp chatbotarena.json s3://sagemaker-us-east-1-342942554664/chatbotarena.json
# Out:
# upload: ./chatbotarena.json to s3://sagemaker-us-east-1-342942554664/chatbotarena.json

# %%
# !aws s3 cp lifearchitectmodels.csv s3://sagemaker-us-east-1-342942554664/lifearchitectmodels.csv
# Out:
# upload: ./lifearchitectmodels.csv to s3://sagemaker-us-east-1-342942554664/lifearchitectmodels.csv

# %%
# !aws s3 cp llmachievements.csv s3://sagemaker-us-east-1-342942554664/llmachievements.csv
# Out:
# upload: ./llmachievements.csv to s3://sagemaker-us-east-1-342942554664/llmachievements.csv

# %%
# !aws s3 cp llmpricingdata.csv s3://sagemaker-us-east-1-342942554664/llmpricingdata.csv
# Out:
# upload: ./llmpricingdata.csv to s3://sagemaker-us-east-1-342942554664/llmpricingdata.csv

# %%
# !aws s3 cp openllmleader.csv s3://sagemaker-us-east-1-342942554664/openllmleader.csv
# Out:
# upload: ./openllmleader.csv to s3://sagemaker-us-east-1-342942554664/openllmleader.csv

# %%
# !aws s3 cp overviewaimodels.csv s3://sagemaker-us-east-1-342942554664/overviewaimodels.csv
# Out:
# upload: ./overviewaimodels.csv to s3://sagemaker-us-east-1-342942554664/overviewaimodels.csv

# %%
# !aws s3 ls s3://sagemaker-us-east-1-342942554664
# Out:
#                            PRE DEMO-breast-cancer-prediction-xgboost-highlevel/
#                            PRE athena/
#                            PRE sagemaker-xgboost-2026-02-10-04-15-54-047/
#                            PRE sagemaker-xgboost-2026-02-10-04-21-39-282/
#                            PRE sagemaker-xgboost-2026-02-10-04-27-59-642/
#                            PRE sagemaker-xgboost-2026-02-10-04-34-04-013/
#                            PRE sagemaker-xgboost-2026-02-10-04-40-01-401/
#                            PRE sagemaker-xgboost-2026-02-10-04-48-49-547/
#                            PRE sagemaker-xgboost-2026-02-10-04-54-11-436/
#                            PRE sagemaker/
#                            PRE table1/
#                            PRE table2/
#                            PRE table3/
#                            PRE test_upload/
# 2026-02-12 09:16:22       7312 aimodelpoll.csv
# 2026-02-12 09:16:26  113342632 chatbotarena.json
# ...
